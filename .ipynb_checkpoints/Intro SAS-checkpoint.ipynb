# %% [markdown]
# SAS (Statistical Analytics System) is a Data Analysis tool
#
#
# ![Capture.JPG](attachment:Capture.JPG)
#
#
# ---
#
#
# Good graphical capabilities and understanding of data
#
# Language inspired from SQL
#
# Claim: 70% market uses SAS
#
# --
#
# ![SASInfo.JPG](attachment:SASInfo.JPG)
#
# ---

# %%
/*By Running the code below
I am able to import allt he data from data.csv
break it down to the 32x527 elements*/

data csvdata;
  missing M B; /*For missing values in Diagnosis which were returning as '.'*/
  infile "/folders/myfolders/data.csv" delimiter=',' firstobs=2 ;
  input id  diagnosis  radius_mean	texture_mean	perimeter_mean 	area_mean	smoothness_mean 	compactness_mean	concavity_mean 	concave_points_mean 	symmetry_mean	fractal_dimension_mean 	radius_se	texture_se 	perimeter_se 	area_se 	smoothness_se 	compactness_se 	concavity_se 	concave_points_se 	symmetry_se	fractal_dimension_se 	radius_worst	texture_worst 	perimeter_worst	area_worst 	smoothness_worst 	compactness_worst 	concavity_worst 	concave points_worst 	symmetry_worst	fractal_dimension_worst;
  proc sql;
      select * from csvdata;
  quit;
  
  run;
# Out:
#   File "<ipython-input-1-9647926bf121>", line 2
#     I am able to import allt he data from data.csv
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# You can also just use the Import process in 'Visual Programmer' and do the same thing
# - this is prolly the most common method used; but its good to know how to do this stuff from the lower level as well
#
#
# Code produced:
#
# /* Generated Code (IMPORT) */
# /* Source File: data.csv */
# /* Source Path: /folders/myfolders */
# /* Code generated on: 7/21/20, 1:37 PM */
#
# %web_drop_table(WORK.IMPORT);
#
#
# FILENAME REFFILE '/folders/myfolders/data.csv';
#
# PROC IMPORT DATAFILE=REFFILE
# 	DBMS=CSV
# 	OUT=WORK.IMPORT;
# 	GETNAMES=YES;
# RUN;
#
# PROC CONTENTS DATA=WORK.IMPORT; RUN;
#
#
# %web_open_table(WORK.IMPORT);
